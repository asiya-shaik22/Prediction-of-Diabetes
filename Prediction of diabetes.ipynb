# %%
# Step 1: Import depending libraries like pandas,numpy and matplotlib

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Download the dataset
## Load your data using pandas library

# %%
df = pd.read_excel('pima.xlsx')
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age  diabetes_orig    skin  has_diabetes  diabetes
# 0        0.627   50              1  1.3790          True      True
# ...

# %%
# To display entire dataset

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# 5           5           116            74          0        0  25.6
# 6           3            78            50         32       88  31.0
# 7          10           115             0          0        0  35.3
# 8           2           197            70         45      543  30.5
# 9           8           125            96          0        0   0.0
# 10          4           110            92          0        0  37.6
# 11         10           168            74          0        0  38.0
# 12         10           139            80          0        0  27.1
# ...

# %%
# To reset above option
pd.reset_option('display.max_rows',None)
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age  diabetes_orig    skin  has_diabetes  diabetes
# 0        0.627   50              1  1.3790          True      True
# ...

# %%
df.columns
# Out:
# Index(['num_preg', 'glucose_conc', 'diastolic_bp', 'thickness', 'insulin',
#        'bmi', 'diab_pred', 'age', 'diabetes_orig', 'skin', 'has_diabetes',
#        'diabetes'],
#       dtype='object')

# %%
#To return number of rows and columns
df.shape
# Out:
# (768, 12)

# %%
# Step 2: Cleaning the dataset
## A. Finding the null values in our dataset

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# num_preg         0
# glucose_conc     0
# diastolic_bp     0
# thickness        0
# insulin          0
# bmi              0
# diab_pred        0
# age              0
# diabetes_orig    0
# skin             0
# has_diabetes     0
# diabetes         0
# dtype: int64

# %%
## B. Finding corelation between columns

# %%
corr = df.corr() # corr is a function used to find corelation between columns
fig,ax = plt.subplots(figsize=(8,8))
cmap = 'plasma'
ax.matshow(corr,cmap=cmap)
plt.xticks(range(len(corr.columns)),corr.columns,rotation =60)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.show()

# %%
# Corelated columns are --
# thickness and skin
# diabetes_origin and has_diabetes
# has_diabetes and diabetes
# diabetes_origin and diabetes

# %%
df.drop('thickness',axis=1,inplace=True)
df.drop('diabetes_orig',axis=1,inplace=True)
df.drop('has_diabetes',axis=1,inplace=True)

# %%
# Check whether the columns are deleted
corr = df.corr()
fig,ax = plt.subplots(figsize=(8,8))
cmap = 'viridis'
ax.matshow(corr,cmap=cmap)
plt.xticks(range(len(corr.columns)),corr.columns,rotation =60)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.show()

# %%
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0           6           148            72        0  33.6      0.627   50
# 1           1            85            66        0  26.6      0.351   31
# 2           8           183            64        0  23.3      0.672   32
# 3           1            89            66       94  28.1      0.167   21
# 4           0           137            40      168  43.1      2.288   33
# ..        ...           ...           ...      ...   ...        ...  ...
# 763        10           101            76      180  32.9      0.171   63
# 764         2           122            70        0  36.8      0.340   27
# 765         5           121            72      112  26.2      0.245   30
# 766         1           126            60        0  30.1      0.349   47
# 767         1            93            70        0  30.4      0.315   23
#
#        skin  diabetes
# 0    1.3790      True
# 1    1.1426     False
# ...

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0         6           148            72        0  33.6      0.627   50
# 1         1            85            66        0  26.6      0.351   31
# 2         8           183            64        0  23.3      0.672   32
# 3         1            89            66       94  28.1      0.167   21
# 4         0           137            40      168  43.1      2.288   33
#
#      skin  diabetes
# 0  1.3790      True
# 1  1.1426     False
# 2  0.0000      True
# 3  0.9062     False
# 4  1.3790      True

# %%
# Check if string data is available
# if available, replace with integer data because model cannot understand string data

# %%
# Creating a dictionary to convert True to 1 and False to 0 [in diabetes column]
dict1 = {
    'diabetes':[True,False]
}
# Inplace of True with 1 and inplace False with 0
dict2 = {
    'diabetes':[1,0]
}

# %%
df.replace(dict1,dict2,inplace=True)
# Out:
# <ipython-input-22-62e0361307d4>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(dict1,dict2,inplace=True)

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0         6           148            72        0  33.6      0.627   50
# 1         1            85            66        0  26.6      0.351   31
# 2         8           183            64        0  23.3      0.672   32
# 3         1            89            66       94  28.1      0.167   21
# 4         0           137            40      168  43.1      2.288   33
#
#      skin  diabetes
# 0  1.3790         1
# 1  1.1426         0
# 2  0.0000         1
# 3  0.9062         0
# 4  1.3790         1

# %%
# C. Check Proportion for diabetes vs non diabetes
num_true = len(df.loc[df['diabetes'] == True])
num_false = len(df.loc[df['diabetes'] == False])
print(f'num_true = {num_true}')
print(f'num_false = {num_false}')

per_num_true = (num_true/(num_true+num_false))*100
print(per_num_true)

per_num_false = (num_false/(num_true+num_false))*100
print(per_num_false)

print('True = ',(num_true/(num_true+num_false) )*100)
print('False = ',(num_false/ (num_true+num_false) )*100 )
# Out:
# num_true = 268
# num_false = 500
# 34.89583333333333
# 65.10416666666666
# True =  34.89583333333333
# False =  65.10416666666666

# %%
# Above data is in good proportion - 34 :65
# if it is inbalanced then we need to handle it using sampling techniques

# %%
#Step 3: Train test split

# %%
from sklearn.model_selection import train_test_split
input_columns = ['num_preg', 'glucose_conc', 'diastolic_bp', 'insulin',
                   'bmi', 'diab_pred', 'age',  'skin']

output_column =['diabetes']
x = df[input_columns]
y = df[output_column]
split_test_size = 0.3
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=split_test_size,
                                                 random_state=42)

# %%
print("X_train",x_train)
print('x_test',x_test)
print('y_train',y_train)
print('y_test',y_test)
# Out:
# X_train      num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 334         1            95            60       58  23.9      0.260   22
# 139         5           105            72      325  36.9      0.159   28
# 485         0           135            68      250  42.3      0.365   24
# 547         4           131            68      166  33.1      0.160   28
# 18          1           103            30       83  43.3      0.183   33
# ..        ...           ...           ...      ...   ...        ...  ...
# 71          5           139            64      140  28.6      0.411   26
# 106         1            96           122        0  22.4      0.207   27
# 270        10           101            86        0  45.6      1.136   38
# 435         0           141             0        0  42.4      0.205   29
# 102         0           125            96        0  22.5      0.262   21
#
#        skin
# 334  0.7092
# 139  1.1426
# 485  1.6548
# 547  0.8274
# 18   1.4972
# ...

# %%
# Check the shape of splitted data
print("X_train",x_train.shape)
print('x_test',x_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# X_train (537, 8)
# x_test (231, 8)
# y_train (537, 1)
# y_test (231, 1)

# %%
# Check the proportion of training and testing after splitting
print('{0:0.2f}% in training set'.format((len(x_train)/len(df.index))*100))
print('{0:0.2f}% in training set'.format((len(x_test)/len(df.index))*100))
# Out:
# 69.92% in training set
# 30.08% in training set

# %%
# Check the diabetes and non diabetes cases in training and testing
print('training true:{0} ({1:0.2f}%)'.format(len(y_train[y_train[ : ] == 1]),
                                              len(y_train[y_train[ : ] ==1])/len(y_train) * 100))
print('training False:{0} ({1:0.2f}%)'.format(len(y_train[y_train[ : ] == 0]),
                                              len(y_train[y_train[ : ] ==0])/len(y_train) * 100))
print('Test true:{0} ({1:0.2f}%)'.format(len(y_test[y_test[ : ] == 1]),
                                         len(y_test[y_test[ : ] ==1])/len(y_train) * 100))
print('Test false:{0} ({1:0.2f}%)'.format(len(y_test[y_test[ : ] == 0]),
                                          len(y_test[y_test[ : ] ==0])/len(y_train) * 100))
# Out:
# training true:537 (100.00%)
# training False:537 (100.00%)
# Test true:231 (43.02%)
# Test false:231 (43.02%)

# %%
# Step 4: Post split preparation

# %%
# Check no of zeros in df
total_num_preg = len(df.loc[df['num_preg']== 0])
print(f'number of Rows missing in num_preg column is {total_num_preg}')
total_glucose_conc = len(df.loc[df['glucose_conc']==0])
print(f'number of Rows missing in glucose_conc column is {total_glucose_conc}')
total_diastolic_bp = len(df.loc[df['diastolic_bp']==0])
print(f'number of Rows missing in diastolic_bp column is {total_diastolic_bp}')
total_insulin = len(df.loc[df['insulin']==0])
print(f'number of Rows missing in insulin column is {total_insulin}')
total_bmi = len(df.loc[df['bmi']==0])
print(f'number of Rows missing in bmi column is {total_bmi}')
total_diab_pred = len(df.loc[df['diab_pred']==0])
print(f'number of Rows missing in diab_pred column is {total_diab_pred}')
total_age = len(df.loc[df['age'] ==0])
print(f'number of rows missing in age is {total_age}')
total_skin = len(df.loc[df['skin']==0])
print(f'number of rows missing in skin is {total_skin}')
# Out:
# number of Rows missing in num_preg column is 111
# number of Rows missing in glucose_conc column is 5
# number of Rows missing in diastolic_bp column is 35
# number of Rows missing in insulin column is 374
# number of Rows missing in bmi column is 11
# number of Rows missing in diab_pred column is 0
# number of rows missing in age is 0
# number of rows missing in skin is 227

# %%
from sklearn.impute import SimpleImputer
fill_values = SimpleImputer(missing_values=0,strategy='mean')
x_train = fill_values.fit_transform(x_train) # fit_transform method fills all the zeros with mean values
x_test = fill_values.fit_transform(x_test)

# %%
x_train[0:5]
# Out:
# array([[1.00000000e+00, 9.50000000e+01, 6.00000000e+01, 5.80000000e+01,
#         2.39000000e+01, 2.60000000e-01, 2.20000000e+01, 7.09200000e-01],
#        [5.00000000e+00, 1.05000000e+02, 7.20000000e+01, 3.25000000e+02,
#         3.69000000e+01, 1.59000000e-01, 2.80000000e+01, 1.14260000e+00],
#        [4.34056399e+00, 1.35000000e+02, 6.80000000e+01, 2.50000000e+02,
#         4.23000000e+01, 3.65000000e-01, 2.40000000e+01, 1.65480000e+00],
#        [4.00000000e+00, 1.31000000e+02, 6.80000000e+01, 1.66000000e+02,
#         3.31000000e+01, 1.60000000e-01, 2.80000000e+01, 8.27400000e-01],
#        [1.00000000e+00, 1.03000000e+02, 3.00000000e+01, 8.30000000e+01,
#         4.33000000e+01, 1.83000000e-01, 3.30000000e+01, 1.49720000e+00]])

# %%
# Step 5: Training the algorithms

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB() # creating object for GaussianNB class
nb_model.fit(x_train,y_train.values.ravel()) # Training a model
# Out:
# GaussianNB()

# %%
from sklearn import metrics
nb_predict_model = nb_model.predict(x_train) # Testing a model
print(f'Predicted accuracy { metrics.accuracy_score(y_train,nb_predict_model) }')
# Out:
# Predicted accuracy 0.7541899441340782

# %%
from sklearn import metrics
nb_predict_test = nb_model.predict(x_test)
print(f'Predicted accuracy { metrics.accuracy_score(y_test,nb_predict_test)}')
# Out:
# Predicted accuracy 0.7359307359307359

# %%
print(f'{metrics.confusion_matrix(y_test,nb_predict_test)}')
# Out:
# [[118  33]
#  [ 28  52]]

# %%
print(f'{ metrics.classification_report(y_test,nb_predict_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79       151
#            1       0.61      0.65      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.72      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42) # Creating object to RandomforestClassifier class
rf_model.fit(x_train,y_train.values.ravel()) # Training a machine
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn import metrics
rf_predict_test= rf_model.predict(x_test) # Testing a model
print(f'Predicted accuracy { metrics.accuracy_score(y_test,rf_predict_test) }')
# Out:
# Predicted accuracy 0.7532467532467533

# %%
from sklearn import metrics
rf_predict_model = rf_model.predict(x_train) # Testing a model
print(f'Predicted accuracy { metrics.accuracy_score(y_train,rf_predict_model) }')
# Out:
# Predicted accuracy 1.0

# %%
print(f'{metrics.confusion_matrix(y_test,rf_predict_test)}')
# Out:
# [[120  31]
#  [ 26  54]]

# %%
print(f'{metrics.classification_report(y_test,rf_predict_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81       151
#            1       0.64      0.68      0.65        80
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.73      0.73       231
# weighted avg       0.76      0.75      0.75       231

# %%
from sklearn.neighbors import KNeighborsClassifier

k_neighbor = KNeighborsClassifier()
k_neighbor.fit(x_train,y_train.values.ravel())
# Out:
# KNeighborsClassifier()

# %%
x_pred = k_neighbor.predict(x_test)

print(f'Accuracy = {metrics.accuracy_score(y_test,x_pred)}')
print(f'Confusion matrix = \n{metrics.confusion_matrix(y_test,x_pred)}')
# Out:
# Accuracy = 0.7359307359307359
# Confusion matrix =
# [[119  32]
#  [ 29  51]]

# %%
print(f'Classification report =\n{metrics.classification_report(y_test,x_pred)}')
# Out:
# Classification report =
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80       151
#            1       0.61      0.64      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.71      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %%
# Final Conclusion - For prediction of Diabetes i used 3 algorithms
# naivebayes, RandomForest, KNeighbors

# %%
#compared to 3 algorithms, RandomForest gives highest accuracy
#So, i will prefer random foreset algorithm for diabetes prediction

# %%
from sklearn.svm import SVC
support = SVC()
support.fit(x_train,y_train.values.ravel())
# Out:
# SVC()

# %%
x_pred = support.predict(x_test)
print(f'Accuracy = {metrics.accuracy_score(y_test,x_pred)} ')
print(f'Confusion matrix = \n {metrics.confusion_matrix(y_test,x_pred)}')
# Out:
# Accuracy = 0.7402597402597403
# Confusion matrix =
#  [[133  18]
#  [ 42  38]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
standardized_data = scaler.transform(x)
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.46849198  1.4259954
#    0.90726993]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.36506078 -0.19067191
#    0.53090156]
#  [ 1.23388019  1.94372388 -0.26394125 ...  0.60439732 -0.10558415
#   -1.28821221]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.68519336 -0.27575966
#    0.15453319]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.37110101  1.17073215
#   -1.28821221]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.47378505 -0.87137393
#    0.65635768]]

# %%
rf_model_test = rf_model.predict(x_test) # Testing a model

input_data = [8,183,64,0,23.3,0.672,32,0.0000]

input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

std_data = scaler.transform(input_data_reshaped)
print(std_data)
rf_model_test = rf_model.predict(std_data)
print(rf_model_test)
if(rf_model_test[0] == 0):
    print('The person is not diabetic')
else:
    print('The person is diabetic')
# Out:
# [[ 1.23388019  1.94372388 -0.26394125 -0.69289057 -1.10325546  0.60439732
#   -0.10558415 -1.28821221]]
# [0]
# The person is not diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
